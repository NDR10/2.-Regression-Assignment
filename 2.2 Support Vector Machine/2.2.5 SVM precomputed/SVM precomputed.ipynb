# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Input = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
Output = dataset[['charges']]
Output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Input, Output, test_size = 0.3, random_state = 0)

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0     False       False
# 196    39  32.800         0     False       False
# 438    52  46.750         5     False       False
# 183    44  26.410         0     False       False
# 1298   33  27.455         2      True       False
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0      True       False
# 835    42  35.970         2      True       False
# 1216   40  25.080         0      True       False
# 559    19  35.530         0      True       False
# 684    33  18.500         1     False       False
#
# [936 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.svm import SVR
Regressor = SVR(kernel = "precomputed", C = 0.01)
Regressor.fit(X_train, Y_train)
# Out:
# C:\Users\dilip\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 from sklearn.svm import SVR
#       2 Regressor = SVR(kernel = "precomputed", C = 0.01)
# ----> 3 Regressor.fit(X_train, Y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:215, in BaseLibSVM.fit(self, X, y, sample_weight)
#     209     raise ValueError(
#     210         "X and y have incompatible shapes.\n"
#     211         + "X has %s samples, but y has %s." % (n_samples, y.shape[0])
#     212     )
#     214 if self.kernel == "precomputed" and n_samples != X.shape[1]:
# --> 215     raise ValueError(
#     216         "Precomputed matrix must be a square matrix."
#     217         " Input is a {}x{} matrix.".format(X.shape[0], X.shape[1])
#     218     )
#     220 if sample_weight.shape[0] > 0 and sample_weight.shape[0] != n_samples:
#     221     raise ValueError(
#     222         "sample_weight and X have incompatible shapes: "
#     223         "%r vs %r\n"
#    (...)
#     226         % (sample_weight.shape, X.shape)
#     227     )
#
# ValueError: Precomputed matrix must be a square matrix. Input is a 936x5 matrix.

# %%
Y_pred = Regressor.predict(X_test)

# %%
bias = Regressor.intercept_
bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 bias = Regressor.intercept_
#       2 bias
#
# AttributeError: 'SVR' object has no attribute 'intercept_'

# %%
Regressor.n_support_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Regressor.n_support_
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:683, in BaseLibSVM.n_support_(self)
#     679     return self._n_support
#     680 else:
#     681     # SVR and OneClass
#     682     # _n_support has size 2, we make it size 1
# --> 683     return np.array([self._n_support[0]])
#
# AttributeError: 'SVR' object has no attribute '_n_support'

# %%
Regressor.support_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 Regressor.support_
#
# AttributeError: 'SVR' object has no attribute 'support_'

# %%
Y_pred = Regressor.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 Y_pred = Regressor.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:628, in BaseLibSVM._validate_for_predict(self, X)
#     622     raise ValueError(
#     623         "cannot use sparse input in %r trained on dense data"
#     624         % type(self).__name__
#     625     )
#     627 if self.kernel == "precomputed":
# --> 628     if X.shape[1] != self.shape_fit_[0]:
#     629         raise ValueError(
#     630             "X.shape[1] = %d should be equal to %d, "
#     631             "the number of samples at training time"
#     632             % (X.shape[1], self.shape_fit_[0])
#     633         )
#     634 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     635 # Check that _n_support is consistent with support_vectors
#
# AttributeError: 'SVR' object has no attribute 'shape_fit_'

# %%
from sklearn.metrics import r2_score
r_score = r2_score(Y_test, Y_pred)
r_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 r_score = r2_score(Y_test, Y_pred)
#       3 r_score
#
# NameError: name 'Y_pred' is not defined
